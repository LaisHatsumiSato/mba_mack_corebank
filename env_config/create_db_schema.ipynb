# %% [markdown]
# -Criar banco de dados

# %%
# %sql
create database if not exists bronze_corebank;
create database if not exists silver_corebank;
create database if not exists gold_corebank;

# %% [markdown]
# Catalogo de dados

# %%
spark.sql("create schema if not exists corebank_catalog.bronze_corebank")
spark.sql("create schema if not exists corebank_catalog.silver_corebank")
spark.sql("create schema if not exists corebank_catalog.gold_corebank")

# %% [markdown]
# criar diretórios

# %%
# %python
##dbutils.fs.mkdirs("dbfs:/Workspace/corebank/gold/")
##dbutils.fs.mkdirs("dbfs:/Workspace/corebank/silver/")
##dbutils.fs.mkdirs("dbfs:/Workspace/corebank/bronze/")
##dbutils.fs.mkdirs("dbfs:/Workspace/corebank/bronze/ref/bancos")
