# %%
# %python
# Caminho base da pasta de notebooks
base_path = "/Repos/LaisHatsumiSato/mba_mack_corebank/bronze/bancos"

# Lista dos notebooks a executar (sem extensão)
notebooks = [
    f"{base_path}/1_bancos_gerador",
    f"{base_path}/2_bancos_bronze",
    f"{base_path}/3_bancos_outra_etapa"
]

# Executa cada notebook em sequência
for nb in notebooks:
    print(f"Executando notebook: {nb}")
    result = dbutils.notebook.run(nb, timeout_seconds=0)  # 0 = sem timeout
    print(f"Resultado: {result}")
