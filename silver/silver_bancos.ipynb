# %%
# %sql
CREATE OR REPLACE TABLE corebank_catalog.silver_corebank.silver_bancos AS
SELECT
  id_banco,
  instituicao,
  cnpj,
  cidade,
  agencia,
  estado
FROM corebank_catalog.bronze_corebank.bancos
WHERE id_banco IS NOT NULL;
