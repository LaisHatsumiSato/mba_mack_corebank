# %%
# %sql
use corebank_catalog.bronze_corebank

# %%
# %sql
CREATE TABLE IF NOT EXISTS clientes_outros (
  nome_completo     STRING,
  cpf_cnpj          STRING,
  telefone          STRING,
  email             STRING,
  endereco          STRING,
  id_cliente        STRING,
  id_banco          STRING,
  estado            STRING,
  cidade            STRING,
  data_nascimento   STRING,
  chave_pix         STRING
)
USING DELTA
TBLPROPERTIES (
  'delta.autoOptimize.optimizeWrite' = 'true'
);
