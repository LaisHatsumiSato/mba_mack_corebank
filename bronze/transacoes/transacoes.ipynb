# %%
# %sql
use bronze_corebank

# %%
# %sql
use corebank_catalog.bronze_corebank

# %%
# %sql
CREATE TABLE IF NOT EXISTS transacao_pix (
  id_cliente STRING,
  id_transacao STRING,
  id_banco STRING,
  id_banco_destino STRING,
  id_cliente_destino STRING,
  valor_transacao STRING,
  dt_hr_transacao STRING
)
USING DELTA;
