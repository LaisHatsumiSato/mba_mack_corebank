# %%
# %sql
use bronze_corebank

# %%
# %sql
CREATE TABLE IF NOT EXISTS bancos (
  id_banco STRING,
  instituicao STRING,
  cnpj STRING,
  cidade STRING,
  agencia STRING,
  estado STRING
) USING DELTA
TBLPROPERTIES (
  'delta.autoOptimize.optimizeWrite' = 'true'
);

# %%
# %sql
describe formatted bancos

# %%
# %sql
select * from bancos
